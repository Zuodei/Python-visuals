# %%
# Importing needed packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Reading the data
df = pd.read_csv('movies.csv')

# %%
#Looking at the first few rows of the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Checking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing, 1)))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.3%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Getting the data type for the columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
#              ...
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# Length: 15, dtype: object

# %%
#Changing the data type of columns budget, gross, and votes to integer from float
df['budget'] = pd.to_numeric(df['budget'], errors = 'coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors = 'coerce').fillna(0).astype(int)
df['votes'] = pd.to_numeric(df['votes'], errors = 'coerce').fillna(0).astype(int)

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Extracting the correct year from the 'released' column
df['yearcorrect'] = df['released'].astype(str).str.split().str[2]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el        NaN     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
pd.set_option('display.max_rows', 10)

# %%
#Drop any duplicates

df['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 6412               iDeal Partners Film Fund
# 4007                               i5 Films
# 6793                             i am OTHER
#                        ...
# 3748                     1+2 Seisaku Iinkai
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Budget correlation test
#Company correlation test

# %%
#Scatter plot with budget vs gross

plt.scatter(df['budget'], df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Plot the budget vs gross using seaborn
sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color': 'grey'}, line_kws = {'color': 'purple'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#looking into the correlation

# %%
df.corr(numeric_only = 'TRUE')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222427  0.309212  0.256331  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.169406  0.399451
# votes    0.222427  0.409182  1.000000  0.486931  0.573930  0.309122
# budget   0.309212  0.055665  0.486931  1.000000  0.687124  0.269510
# gross    0.256331  0.169406  0.573930  0.687124  1.000000  0.204177
# runtime  0.120811  0.399451  0.309122  0.269510  0.204177  1.000000

# %%
#Pearson correlation
df.corr(method = 'pearson', numeric_only = 'TRUE')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222427  0.309212  0.256331  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.169406  0.399451
# votes    0.222427  0.409182  1.000000  0.486931  0.573930  0.309122
# budget   0.309212  0.055665  0.486931  1.000000  0.687124  0.269510
# gross    0.256331  0.169406  0.573930  0.687124  1.000000  0.204177
# runtime  0.120811  0.399451  0.309122  0.269510  0.204177  1.000000

# %%
#Kendall correlation
df.corr(method = 'kendall', numeric_only = 'TRUE')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.330410  0.209304  0.215943  0.097184
# score    0.067652  1.000000  0.300115 -0.005194  0.089155  0.283611
# votes    0.330410  0.300115  1.000000  0.439883  0.558897  0.197948
# budget   0.209304 -0.005194  0.439883  1.000000  0.540326  0.176016
# gross    0.215943  0.089155  0.558897  0.540326  1.000000  0.175355
# runtime  0.097184  0.283611  0.197948  0.176016  0.175355  1.000000

# %%
#Spearman correlation
df.corr(method = 'spearman', numeric_only = 'TRUE')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.468107  0.291152  0.313716  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.130397  0.399857
# votes    0.468107  0.428138  1.000000  0.604693  0.750227  0.289726
# budget   0.291152 -0.007500  0.604693  1.000000  0.714457  0.246748
# gross    0.313716  0.130397  0.750227  0.714457  1.000000  0.254471
# runtime  0.142977  0.399857  0.289726  0.246748  0.254471  1.000000

# %%
#High correlation between budget and gross is existent

# %%
#Visualizing the correlation 
correlation_matrix = df.select_dtypes(include=[np.number]).corr(method='pearson').fillna(0)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Budget for film') 
plt.show()

# %%
#Looking at company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Numerizing non-numeric columns
for col in df.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized #I used df_numerized to retian the original non-numerized data
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3      286       4      4  1980      1492    7.7   221000      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000      1054     521
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36       774    2614
# 7665  4717      -1      6  2020       193    5.7       29      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        0      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7      2165    3344
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Visualizing the correlation for the numerized data
correlation_matrix = df_numerized.select_dtypes(include=[np.number]).corr(method='pearson').fillna(0)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Budget for film') 
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# ...               ...       ...       ...       ...       ...       ...
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# gross        0.013895 -0.095355 -0.229534  0.256331  0.014154  0.169406
# company      0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.001030
# runtime      0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
# yearcorrect  0.010071  0.008230 -0.078972  0.990063 -0.006411  0.103330
#
#                 votes  director    writer      star   country    budget  \
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget         0.300649
#              gross          0.249548
#              company       -0.011060
#              runtime        0.120976
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
pd.set_option('display.max_rows', 10)

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
# gross        genre         -0.229534
# genre        gross         -0.229534
#              votes         -0.145296
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross        votes          0.573930
# votes        gross          0.573930
# budget       gross          0.687124
# gross        budget         0.687124
# year         yearcorrect    0.990063
#                               ...
#              year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 22, dtype: float64

# %%
#Votes and budget have the highest correlation to gross earnings

#Company has a low correlation to the gross of the film
